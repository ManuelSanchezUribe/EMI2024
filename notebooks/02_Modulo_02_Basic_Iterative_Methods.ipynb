# %% [markdown]
# <hr style="border:2px solid #0176DE"> </hr>
# <center><h1 style="color:#173F8A;"> Escuela de Verano en Metodos Iterativos</h1></center>
# <center><h1 style="color:#173F8A;"> EMI 2024 - CMM Chile</h1></center>
# <hr style="border:2px solid #0176DE"> </hr>
# <h3 style="color:#173F8A;text-align:right;"> Profesores: &nbsp;Nicolas Barnafi<br>Manuel A. Sanchez<br></h3>
#
# <h3 style="color:#03122E;text-align:right;">
#     Centro de Modelamiento Matematico <br>
#     Instituto de Ingenieria Matematica y Computacional - IMC UC<br>
# </h3>
#
# <hr style="border:2px solid #03122E"> </hr>
# <center><h1 style="color:#173F8A;"> Modulo 2: Basic Iterative Methods</h1></center>
# <hr style="border:2px solid #03122E"> </hr>
#
# <!-- Palette colors UC:
# Primaria:
# celeste:#0176DE, azul #173F8A, azul oscuro: #03122E, amarillo: #FEC60D, amarillo oscuro: #E3AE00
# Secundaria
# gris oscuro: #707070
# -->

# %% [markdown]
# ## Objective: Review basic iterative Method for solving the linear systems.
#
# Let $A\in \mathbb R^{n\times n}$ and $b\in \mathbb R^{n}$. Consider the problem of finding $x\in \mathbb R^{n}$ such that
#
# $$
# Ax = b
# $$

# %% [markdown]
# ### General splitting for iteration methods.
#
# A basic iterative method given by the iteration
# $$
# M x_{k+1} = N x_{k} + b
# $$
# can be defined for any splitting of the form $A = M- N$ where $M$ is nonsingular. The matrix $G = M^{-1}N$ is known as the *iteration matrix* of the methods,
# $$
# x_{k+1} = G x_{k} + f, \quad f = M^{-1} b
# $$
#
# If the above iteration converges, its limit $x$ satisfies
#
# $$
# x = Gx + f
# $$
#
# In the case where the above iteration arises from the splitting $A=M-N$, it is easy to see that the solution $x$ to the above system is identical to that of the original system $Ax=b$. Indeed, in this case the sequence has the from
#
# $$
# x_{k+1} = M^{-1} N x_{k} + M^{-1} b
# $$
#
# and its limit satisfies
#
# $$
# Mx = Nx +b \quad \Longleftrightarrow \quad Ax = b
# $$

# %% [markdown]
# ### General convergence result
#
# ***Theorem***. Let $G$ be a square matrix such that $\rho(G)<1$. Then $(I-G)$ is nonsingular and the iteration $x_{k+1} = G x_{k} + f$ converges for any $f$ and $x_0$. Conversely, if the iteration converges for any $f$ and $x_0$, then $\rho(G)<1$.
#
# Here the spectal radius $\rho(A)$ of a matrix $A$ is defined as the maximum modulus of the eigenvalues of $A$, i.e.
#
# $$
# \rho(A) = \max_{\lambda \in \sigma(A)} |\lambda|
# $$
#
# ***Corollary***. Let $G$ be a square matrix such that $\|G\|<1$ for some matrix norm $\|\cdot\|$. Then $(I-G)$ is nonsingular and the iteration converges for any initial vector $x_0$.
#
# <h3 style="color:#0176DE">
#     How fast does the iteration converge?
# </h3>
#
# Define the error at step k $d_{k} = x_{k} - x_{*}$. Observe that
#
# $$
# d_{k} = x_{k} - x_{*} = G x_{k-1} + f - G x_{*} - f = G d_{k-1} = \ldots = G^{k} d_0
# $$
#
# <!-- The matrix $G$ can be expressed in the Jordan canonical form as $G = X J X^{-1}$. Assume for simplicity that there is only one eigenvalue of $G$ of largest modulus $\lambda = \rho(A)$. Then,
#
# $$
# d_{k} = \lambda^{k} X \left(\frac{1}{\lambda} J\right)^{k} X^{-1} d_0
# $$
#
# Only one Jordan block remains of size p $J_{\lambda} = \lambda I + E$, with $E$ nilpotente of index $p$. Then, for $k\geq p$
#
# $$
# J_{\lambda}^{k} = (\lambda I+E)^{k} = \lambda^{k}(I + \frac{1}{\lambda}E)^{k} = \lambda^{k} \left(\sum_{i=0}^{p-1} \lambda^{-i} {k \choose i}E^{i}\right)
# $$
#
# For any $\lambda$ the dominant term is the last term of $k$ arge enough
#
# $$
# J_{\lambda}^{k} \approx \lambda^{k-p+1} {k \choose p-1} E^{p-1}
# $$
#
# and thus,
#
# \|d_{k}\| \approx C |\lambda^{k-p+1}| {k \choose p-1}
#  -->
# A general convergence factor:
#
# $$
# \phi = \lim_{k\to \infty} \left( \max_{x_0\in \mathbb R^{n} } \frac{\|d_k\|}{\|d_0\|}\right)^{1/k}
# $$
#
# In this case
#
# $$
# \phi = \lim_{k \to \infty}\left( \max_{x_0\in \mathbb R^{n} } \frac{\|G^{k} d_0\|}{\|d_0\|}\right)^{1/k} = \lim_{k \to \infty}\left( \|G^{k}\|\right)^{1/k} = \rho(G).
# $$
#
# The global asymptotic factor is equal to the spectral radius of the iteration matrix.

# %% [markdown]
# #### Ejemplo: Richardson's iteration
# For $\alpha \geq 0$, consider the iteration
#
# $$
# x_{k+1} = x_{k} +\alpha (b-A x_{k})\quad \Longrightarrow \quad x_{k+1} = \underbrace{(I-\alpha A)}_{G_{\alpha}}x_{k} + \alpha b
# $$
#
# The convergence factor is $\rho(I-\alpha A). Assume that the eigenvalues $\lambda_i$, $1\leq i\leq n$,  of $A$ are all real and such that
#
# $$\lambda_{\min} \leq \lambda_i \leq \lambda_{\max} $$
#
# Then, the eigenvalues $\mu_i$ of $G_{\alpha}$ are such that
#
# $$ 1- \alpha\lambda_{\max} \leq \mu_i \leq 1 - \alpha \lambda_{\min} $$
#
# If $\lambda_{\min} < 0$ and $\lambda_{\max} >0 $ , at leaast one eigenvalue is $>1$, and so $\rho(G_{\alpha})>1$, for any $\alpha$,and the method diverges for any $x_0$.
#
# If all the eigenvalues are positive, $\lambda_{\min}>0$, then the method converges for any scalar $\alpha$ which satisfies
#
# $$
# 0<\alpha<2/\lambda_{\max}.
# $$
#
# Optimal $\alpha$?
#
# $$
# \alpha_{\text{opt}} = \frac{2}{\lambda_{\min} + \lambda_{\max}}
# $$

# %% [markdown]
# **Decomposition:** $ \quad A = D -E - F$, $D$ diagonal matrix, $E$ strict lower triangular, and $F$ strict upper triangular.
#
#
# #### Jacobi Iteration:
# $$
# x_{k+1} = D^{-1}(E+F)x_{k} + D^{-1}b
# $$
#
# $$
# x_{k+1} = -D^{-1}(A-D)x_{k} + D^{-1}b = -D^{-1}(A)x_{k} + x_{k}+ D^{-1}b
# $$
#
# $$
# x_{k+1} - x_{k}= \Delta x_{k+1}  = -D^{-1}(A)x_{k}+ D^{-1}b
# $$
#
# #### Gauss-Seidel Iteration:
# $$
# x_{k+1} = (D-E)^{-1} F x_{k} + (D-E)^{-1}b
# $$
#
# #### Successive Over Relaxation (SOR):
# $$
# (D-\omega E)x_{k+1} = \left( \omega F +(1-\omega)D\right) x_{k} + \omega b
# $$
#
# #### Symmetric SOR (SSOR):
# \begin{align*}
# (D-\omega E) x_{k+1/2} & = \left( \omega F + (1-\omega)D\right) x_{k} + \omega b \\
# (D-\omega F) x_{k+1} & = \left(\omega E + (1-\omega)D\right) x_{k+1/2} + \omega b
# \end{align*}

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from ngsolve.la import EigenValues_Preconditioner
import matplotlib.pyplot as plt

# %%
# Poisson problem
def Setup(h=0.01, p=1):
    mesh = Mesh(unit_square.GenerateMesh(maxh=h))
    fes = H1(mesh, order=p, dirichlet="left|bottom")
    u, v = fes.TnT()
    a = BilinearForm(grad(u)*grad(v)*dx + u*v*dx)
    f = LinearForm(v*dx)
    gfu = GridFunction(fes)
    return mesh, fes, a, f, gfu

# %%
mesh, fes, a, b, gfu = Setup(h=0.05, p=1)
a.Assemble()
b.Assemble();
Draw(gfu)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.22…
# BaseWebGuiScene

# %%
def JacobiIteration(gfu, a, b, maxits=300, tol=1e-8):
    fes = gfu.space
    du = gfu.vec.CreateVector()
    res = gfu.vec.CreateVector()
    diag = (a.mat.CreateSmoother(fes.FreeDofs()))
    f = diag*b.vec
    for it in range(maxits):
        res.data = -a.mat*gfu.vec
        du.data = diag*res+ f
        gfu.vec.data += du
        
        #stopping criteria
        stopcritval = sqrt(abs(InnerProduct(du,du)))
        print ("<du",it,", du",it,">_{-1}^0.5 = ", stopcritval)
        if stopcritval < tol:
            break

# %%
JacobiIteration(gfu, a, b)
# Out:
# <du 0 , du 0 >_{-1}^0.5 =  0.013440989653890751
# <du 1 , du 1 >_{-1}^0.5 =  0.012989765785627225
# <du 2 , du 2 >_{-1}^0.5 =  0.012765402770661164
# <du 3 , du 3 >_{-1}^0.5 =  0.012598647351105054
# <du 4 , du 4 >_{-1}^0.5 =  0.012456754226082084
# <du 5 , du 5 >_{-1}^0.5 =  0.012332120434158343
# <du 6 , du 6 >_{-1}^0.5 =  0.012217923167622746
# <du 7 , du 7 >_{-1}^0.5 =  0.012112317031616962
# <du 8 , du 8 >_{-1}^0.5 =  0.012012880585084857
# <du 9 , du 9 >_{-1}^0.5 =  0.011918800455717289
# <du 10 , du 10 >_{-1}^0.5 =  0.011828996271154532
# <du 11 , du 11 >_{-1}^0.5 =  0.011742994311814501
# <du 12 , du 12 >_{-1}^0.5 =  0.011660230362125646
# <du 13 , du 13 >_{-1}^0.5 =  0.01158038955405332
# <du 14 , du 14 >_{-1}^0.5 =  0.011503137181809444
# <du 15 , du 15 >_{-1}^0.5 =  0.011428248948733755
# <du 16 , du 16 >_{-1}^0.5 =  0.01135550476467695
# <du 17 , du 17 >_{-1}^0.5 =  0.011284737683973757
# <du 18 , du 18 >_{-1}^0.5 =  0.01121579115252766
# <du 19 , du 19 >_{-1}^0.5 =  0.011148536781061633
# <du 20 , du 20 >_{-1}^0.5 =  0.011082856665770021
# <du 21 , du 21 >_{-1}^0.5 =  0.01101864941735634
# <du 22 , du 22 >_{-1}^0.5 =  0.010955822549117658
# <du 23 , du 23 >_{-1}^0.5 =  0.010894294202796148
# <du 24 , du 24 >_{-1}^0.5 =  0.010833989669035567
# <du 25 , du 25 >_{-1}^0.5 =  0.010774841618362192
# <du 26 , du 26 >_{-1}^0.5 =  0.010716788374866483
# <du 27 , du 27 >_{-1}^0.5 =  0.010659773686575655
# <du 28 , du 28 >_{-1}^0.5 =  0.010603745780286689
# <du 29 , du 29 >_{-1}^0.5 =  0.010548657035557294
# <du 30 , du 30 >_{-1}^0.5 =  0.01049446341206936
# <du 31 , du 31 >_{-1}^0.5 =  0.010441124143940102
# <du 32 , du 32 >_{-1}^0.5 =  0.010388601360520939
# <du 33 , du 33 >_{-1}^0.5 =  0.010336859829826586
# <du 34 , du 34 >_{-1}^0.5 =  0.01028586668956955
# <du 35 , du 35 >_{-1}^0.5 =  0.010235591239677048
# <du 36 , du 36 >_{-1}^0.5 =  0.010186004741929301
# <du 37 , du 37 >_{-1}^0.5 =  0.010137080253798395
# <du 38 , du 38 >_{-1}^0.5 =  0.010088792474023165
# <du 39 , du 39 >_{-1}^0.5 =  0.01004111760928779
# <du 40 , du 40 >_{-1}^0.5 =  0.009994033252307627
# <du 41 , du 41 >_{-1}^0.5 =  0.009947518274127388
# <du 42 , du 42 >_{-1}^0.5 =  0.00990155272615453
# <du 43 , du 43 >_{-1}^0.5 =  0.00985611775240329
# <du 44 , du 44 >_{-1}^0.5 =  0.009811195509681531
# <du 45 , du 45 >_{-1}^0.5 =  0.009766769095445424
# <du 46 , du 46 >_{-1}^0.5 =  0.009722822482042042
# <du 47 , du 47 >_{-1}^0.5 =  0.009679340456884138
# <du 48 , du 48 >_{-1}^0.5 =  0.00963630856775486
# <du 49 , du 49 >_{-1}^0.5 =  0.009593713072797161
# <du 50 , du 50 >_{-1}^0.5 =  0.009551540894640238
# <du 51 , du 51 >_{-1}^0.5 =  0.009509779578281462
# <du 52 , du 52 >_{-1}^0.5 =  0.009468417252326517
# <du 53 , du 53 >_{-1}^0.5 =  0.00942744259327557
# <du 54 , du 54 >_{-1}^0.5 =  0.00938684479255538
# <du 55 , du 55 >_{-1}^0.5 =  0.009346613526046087
# <du 56 , du 56 >_{-1}^0.5 =  0.009306738925869832
# <du 57 , du 57 >_{-1}^0.5 =  0.009267211554239525
# <du 58 , du 58 >_{-1}^0.5 =  0.009228022379183985
# <du 59 , du 59 >_{-1}^0.5 =  0.009189162751987058
# <du 60 , du 60 >_{-1}^0.5 =  0.00915062438619353
# <du 61 , du 61 >_{-1}^0.5 =  0.009112399338050707
# <du 62 , du 62 >_{-1}^0.5 =  0.009074479988266496
# <du 63 , du 63 >_{-1}^0.5 =  0.00903685902497724
# <du 64 , du 64 >_{-1}^0.5 =  0.008999529427828168
# <du 65 , du 65 >_{-1}^0.5 =  0.008962484453078986
# <du 66 , du 66 >_{-1}^0.5 =  0.008925717619654857
# <du 67 , du 67 >_{-1}^0.5 =  0.008889222696070492
# <du 68 , du 68 >_{-1}^0.5 =  0.00885299368816152
# <du 69 , du 69 >_{-1}^0.5 =  0.008817024827563098
# <du 70 , du 70 >_{-1}^0.5 =  0.00878131056088103
# <du 71 , du 71 >_{-1}^0.5 =  0.008745845539505291
# <du 72 , du 72 >_{-1}^0.5 =  0.008710624610019974
# <du 73 , du 73 >_{-1}^0.5 =  0.008675642805167949
# <du 74 , du 74 >_{-1}^0.5 =  0.0086408953353313
# <du 75 , du 75 >_{-1}^0.5 =  0.0086063775804924
# <du 76 , du 76 >_{-1}^0.5 =  0.008572085082642842
# <du 77 , du 77 >_{-1}^0.5 =  0.008538013538610233
# <du 78 , du 78 >_{-1}^0.5 =  0.008504158793275332
# <du 79 , du 79 >_{-1}^0.5 =  0.008470516833153675
# <du 80 , du 80 >_{-1}^0.5 =  0.008437083780318395
# <du 81 , du 81 >_{-1}^0.5 =  0.008403855886642246
# <du 82 , du 82 >_{-1}^0.5 =  0.008370829528338612
# <du 83 , du 83 >_{-1}^0.5 =  0.008338001200782938
# <du 84 , du 84 >_{-1}^0.5 =  0.008305367513597032
# <du 85 , du 85 >_{-1}^0.5 =  0.008272925185980325
# <du 86 , du 86 >_{-1}^0.5 =  0.008240671042272935
# <du 87 , du 87 >_{-1}^0.5 =  0.008208602007736824
# <du 88 , du 88 >_{-1}^0.5 =  0.008176715104542
# <du 89 , du 89 >_{-1}^0.5 =  0.008145007447945727
# <du 90 , du 90 >_{-1}^0.5 =  0.008113476242653623
# <du 91 , du 91 >_{-1}^0.5 =  0.008082118779352044
# <du 92 , du 92 >_{-1}^0.5 =  0.008050932431402104
# <du 93 , du 93 >_{-1}^0.5 =  0.008019914651686255
# <du 94 , du 94 >_{-1}^0.5 =  0.007989062969598807
# <du 95 , du 95 >_{-1}^0.5 =  0.007958374988172541
# <du 96 , du 96 >_{-1}^0.5 =  0.007927848381333884
# <du 97 , du 97 >_{-1}^0.5 =  0.007897480891279859
# <du 98 , du 98 >_{-1}^0.5 =  0.00786727032597006
# <du 99 , du 99 >_{-1}^0.5 =  0.007837214556727784
# <du 100 , du 100 >_{-1}^0.5 =  0.007807311515944383
# <du 101 , du 101 >_{-1}^0.5 =  0.007777559194881641
# <du 102 , du 102 >_{-1}^0.5 =  0.007747955641567031
# <du 103 , du 103 >_{-1}^0.5 =  0.007718498958777198
# <du 104 , du 104 >_{-1}^0.5 =  0.00768918730210511
# <du 105 , du 105 >_{-1}^0.5 =  0.007660018878106832
# <du 106 , du 106 >_{-1}^0.5 =  0.007630991942523884
# <du 107 , du 107 >_{-1}^0.5 =  0.007602104798577568
# <du 108 , du 108 >_{-1}^0.5 =  0.007573355795331646
# <du 109 , du 109 >_{-1}^0.5 =  0.0075447433261202875
# <du 110 , du 110 >_{-1}^0.5 =  0.007516265827037982
# <du 111 , du 111 >_{-1}^0.5 =  0.007487921775488654
# <du 112 , du 112 >_{-1}^0.5 =  0.007459709688791103
# <du 113 , du 113 >_{-1}^0.5 =  0.007431628122838273
# <du 114 , du 114 >_{-1}^0.5 =  0.007403675670807845
# <du 115 , du 115 >_{-1}^0.5 =  0.007375850961921763
# <du 116 , du 116 >_{-1}^0.5 =  0.007348152660252641
# <du 117 , du 117 >_{-1}^0.5 =  0.007320579463574891
# <du 118 , du 118 >_{-1}^0.5 =  0.007293130102258521
# <du 119 , du 119 >_{-1}^0.5 =  0.007265803338203893
# <du 120 , du 120 >_{-1}^0.5 =  0.007238597963815617
# <du 121 , du 121 >_{-1}^0.5 =  0.00721151280101385
# <du 122 , du 122 >_{-1}^0.5 =  0.007184546700281443
# <du 123 , du 123 >_{-1}^0.5 =  0.0071576985397455144
# <du 124 , du 124 >_{-1}^0.5 =  0.007130967224291886
# <du 125 , du 125 >_{-1}^0.5 =  0.007104351684711052
# <du 126 , du 126 >_{-1}^0.5 =  0.007077850876874452
# <du 127 , du 127 >_{-1}^0.5 =  0.007051463780939815
# <du 128 , du 128 >_{-1}^0.5 =  0.007025189400584295
# <du 129 , du 129 >_{-1}^0.5 =  0.006999026762264386
# <du 130 , du 130 >_{-1}^0.5 =  0.006972974914501554
# <du 131 , du 131 >_{-1}^0.5 =  0.0069470329271924805
# <du 132 , du 132 >_{-1}^0.5 =  0.006921199890943119
# <du 133 , du 133 >_{-1}^0.5 =  0.0068954749164254455
# <du 134 , du 134 >_{-1}^0.5 =  0.006869857133756274
# <du 135 , du 135 >_{-1}^0.5 =  0.006844345691896899
# <du 136 , du 136 >_{-1}^0.5 =  0.006818939758073371
# <du 137 , du 137 >_{-1}^0.5 =  0.006793638517215977
# <du 138 , du 138 >_{-1}^0.5 =  0.0067684411714176865
# <du 139 , du 139 >_{-1}^0.5 =  0.006743346939410655
# <du 140 , du 140 >_{-1}^0.5 =  0.00671835505606014
# <du 141 , du 141 >_{-1}^0.5 =  0.0066934647718752405
# <du 142 , du 142 >_{-1}^0.5 =  0.0066686753525357296
# <du 143 , du 143 >_{-1}^0.5 =  0.0066439860784345784
# <du 144 , du 144 >_{-1}^0.5 =  0.006619396244235465
# <du 145 , du 145 >_{-1}^0.5 =  0.006594905158444711
# <du 146 , du 146 >_{-1}^0.5 =  0.006570512142997371
# <du 147 , du 147 >_{-1}^0.5 =  0.006546216532856614
# <du 148 , du 148 >_{-1}^0.5 =  0.0065220176756262006
# <du 149 , du 149 >_{-1}^0.5 =  0.006497914931175522
# <du 150 , du 150 >_{-1}^0.5 =  0.006473907671276717
# <du 151 , du 151 >_{-1}^0.5 =  0.006449995279253523
# <du 152 , du 152 >_{-1}^0.5 =  0.006426177149641384
# <du 153 , du 153 >_{-1}^0.5 =  0.006402452687858471
# <du 154 , du 154 >_{-1}^0.5 =  0.006378821309887266
# <du 155 , du 155 >_{-1}^0.5 =  0.006355282441966248
# <du 156 , du 156 >_{-1}^0.5 =  0.00633183552029147
# <du 157 , du 157 >_{-1}^0.5 =  0.006308479990727663
# <du 158 , du 158 >_{-1}^0.5 =  0.006285215308528354
# <du 159 , du 159 >_{-1}^0.5 =  0.0062620409380650865
# <du 160 , du 160 >_{-1}^0.5 =  0.006238956352564988
# <du 161 , du 161 >_{-1}^0.5 =  0.006215961033856811
# <du 162 , du 162 >_{-1}^0.5 =  0.0061930544721248565
# <du 163 , du 163 >_{-1}^0.5 =  0.006170236165670711
# <du 164 , du 164 >_{-1}^0.5 =  0.006147505620682432
# <du 165 , du 165 >_{-1}^0.5 =  0.006124862351011123
# <du 166 , du 166 >_{-1}^0.5 =  0.006102305877954221
# <du 167 , du 167 >_{-1}^0.5 =  0.006079835730045901
# <du 168 , du 168 >_{-1}^0.5 =  0.006057451442853835
# <du 169 , du 169 >_{-1}^0.5 =  0.0060351525587823245
# <du 170 , du 170 >_{-1}^0.5 =  0.006012938626881684
# <du 171 , du 171 >_{-1}^0.5 =  0.0059908092026633945
# <du 172 , du 172 >_{-1}^0.5 =  0.005968763847921155
# <du 173 , du 173 >_{-1}^0.5 =  0.005946802130557461
# <du 174 , du 174 >_{-1}^0.5 =  0.005924923624415479
# <du 175 , du 175 >_{-1}^0.5 =  0.005903127909116335
# <du 176 , du 176 >_{-1}^0.5 =  0.005881414569901227
# <du 177 , du 177 >_{-1}^0.5 =  0.005859783197478553
# <du 178 , du 178 >_{-1}^0.5 =  0.005838233387875815
# <du 179 , du 179 >_{-1}^0.5 =  0.005816764742296
# <du 180 , du 180 >_{-1}^0.5 =  0.005795376866978369
# <du 181 , du 181 >_{-1}^0.5 =  0.005774069373063706
# <du 182 , du 182 >_{-1}^0.5 =  0.005752841876463642
# <du 183 , du 183 >_{-1}^0.5 =  0.005731693997733861
# <du 184 , du 184 >_{-1}^0.5 =  0.005710625361951528
# <du 185 , du 185 >_{-1}^0.5 =  0.005689635598596144
# <du 186 , du 186 >_{-1}^0.5 =  0.00566872434143438
# <du 187 , du 187 >_{-1}^0.5 =  0.005647891228408192
# <du 188 , du 188 >_{-1}^0.5 =  0.005627135901526547
# <du 189 , du 189 >_{-1}^0.5 =  0.005606458006760351
# <du 190 , du 190 >_{-1}^0.5 =  0.005585857193940746
# <du 191 , du 191 >_{-1}^0.5 =  0.005565333116660395
# <du 192 , du 192 >_{-1}^0.5 =  0.0055448854321777956
# <du 193 , du 193 >_{-1}^0.5 =  0.005524513801324667
# <du 194 , du 194 >_{-1}^0.5 =  0.005504217888415994
# <du 195 , du 195 >_{-1}^0.5 =  0.005483997361162891
# <du 196 , du 196 >_{-1}^0.5 =  0.005463851890588216
# <du 197 , du 197 >_{-1}^0.5 =  0.005443781150944656
# <du 198 , du 198 >_{-1}^0.5 =  0.005423784819635288
# <du 199 , du 199 >_{-1}^0.5 =  0.005403862577136713
# <du 200 , du 200 >_{-1}^0.5 =  0.0053840141069243785
# <du 201 , du 201 >_{-1}^0.5 =  0.0053642390954003185
# <du 202 , du 202 >_{-1}^0.5 =  0.0053445372318228525
# <du 203 , du 203 >_{-1}^0.5 =  0.005324908208238844
# <du 204 , du 204 >_{-1}^0.5 =  0.005305351719417613
# <du 205 , du 205 >_{-1}^0.5 =  0.0052858674627869655
# <du 206 , du 206 >_{-1}^0.5 =  0.005266455138371396
# <du 207 , du 207 >_{-1}^0.5 =  0.005247114448731897
# <du 208 , du 208 >_{-1}^0.5 =  0.00522784509890761
# <du 209 , du 209 >_{-1}^0.5 =  0.005208646796359483
# <du 210 , du 210 >_{-1}^0.5 =  0.005189519250915401
# <du 211 , du 211 >_{-1}^0.5 =  0.0051704621747170765
# <du 212 , du 212 >_{-1}^0.5 =  0.005151475282168536
# <du 213 , du 213 >_{-1}^0.5 =  0.005132558289886121
# <du 214 , du 214 >_{-1}^0.5 =  0.005113710916650184
# <du 215 , du 215 >_{-1}^0.5 =  0.005094932883357916
# <du 216 , du 216 >_{-1}^0.5 =  0.005076223912977924
# <du 217 , du 217 >_{-1}^0.5 =  0.005057583730506064
# <du 218 , du 218 >_{-1}^0.5 =  0.005039012062922425
# <du 219 , du 219 >_{-1}^0.5 =  0.0050205086391499785
# <du 220 , du 220 >_{-1}^0.5 =  0.005002073190014137
# <du 221 , du 221 >_{-1}^0.5 =  0.004983705448203773
# <du 222 , du 222 >_{-1}^0.5 =  0.004965405148233113
# <du 223 , du 223 >_{-1}^0.5 =  0.0049471720264052
# <du 224 , du 224 >_{-1}^0.5 =  0.004929005820776006
# <du 225 , du 225 >_{-1}^0.5 =  0.00491090627112001
# <du 226 , du 226 >_{-1}^0.5 =  0.0048928731188964915
# <du 227 , du 227 >_{-1}^0.5 =  0.004874906107217065
# <du 228 , du 228 >_{-1}^0.5 =  0.004857004980814045
# <du 229 , du 229 >_{-1}^0.5 =  0.004839169486009817
# <du 230 , du 230 >_{-1}^0.5 =  0.004821399370687135
# <du 231 , du 231 >_{-1}^0.5 =  0.004803694384260226
# <du 232 , du 232 >_{-1}^0.5 =  0.004786054277646863
# <du 233 , du 233 >_{-1}^0.5 =  0.004768478803241183
# <du 234 , du 234 >_{-1}^0.5 =  0.0047509677148873525
# <du 235 , du 235 >_{-1}^0.5 =  0.004733520767854022
# <du 236 , du 236 >_{-1}^0.5 =  0.004716137718809532
# <du 237 , du 237 >_{-1}^0.5 =  0.004698818325797751
# <du 238 , du 238 >_{-1}^0.5 =  0.004681562348214874
# <du 239 , du 239 >_{-1}^0.5 =  0.004664369546786619
# <du 240 , du 240 >_{-1}^0.5 =  0.004647239683546293
# <du 241 , du 241 >_{-1}^0.5 =  0.0046301725218134224
# <du 242 , du 242 >_{-1}^0.5 =  0.004613167826173051
# <du 243 , du 243 >_{-1}^0.5 =  0.004596225362455516
# <du 244 , du 244 >_{-1}^0.5 =  0.004579344897717084
# <du 245 , du 245 >_{-1}^0.5 =  0.004562526200220929
# <du 246 , du 246 >_{-1}^0.5 =  0.004545769039418597
# <du 247 , du 247 >_{-1}^0.5 =  0.00452907318593234
# <du 248 , du 248 >_{-1}^0.5 =  0.004512438411537605
# <du 249 , du 249 >_{-1}^0.5 =  0.004495864489146296
# <du 250 , du 250 >_{-1}^0.5 =  0.004479351192790334
# <du 251 , du 251 >_{-1}^0.5 =  0.004462898297605801
# <du 252 , du 252 >_{-1}^0.5 =  0.0044465055798174995
# <du 253 , du 253 >_{-1}^0.5 =  0.004430172816723981
# <du 254 , du 254 >_{-1}^0.5 =  0.004413899786682953
# <du 255 , du 255 >_{-1}^0.5 =  0.004397686269097178
# <du 256 , du 256 >_{-1}^0.5 =  0.004381532044400666
# <du 257 , du 257 >_{-1}^0.5 =  0.0043654368940454135
# <du 258 , du 258 >_{-1}^0.5 =  0.004349400600488312
# <du 259 , du 259 >_{-1}^0.5 =  0.004333422947178675
# <du 260 , du 260 >_{-1}^0.5 =  0.004317503718545875
# <du 261 , du 261 >_{-1}^0.5 =  0.00430164269998753
# <du 262 , du 262 >_{-1}^0.5 =  0.004285839677857831
# <du 263 , du 263 >_{-1}^0.5 =  0.004270094439456327
# <du 264 , du 264 >_{-1}^0.5 =  0.004254406773017068
# <du 265 , du 265 >_{-1}^0.5 =  0.004238776467697814
# <du 266 , du 266 >_{-1}^0.5 =  0.0042232033135697865
# <du 267 , du 267 >_{-1}^0.5 =  0.004207687101607664
# <du 268 , du 268 >_{-1}^0.5 =  0.0041922276236795826
# <du 269 , du 269 >_{-1}^0.5 =  0.004176824672537888
# <du 270 , du 270 >_{-1}^0.5 =  0.0041614780418096865
# <du 271 , du 271 >_{-1}^0.5 =  0.0041461875259878765
# <du 272 , du 272 >_{-1}^0.5 =  0.004130952920422428
# <du 273 , du 273 >_{-1}^0.5 =  0.004115774021311793
# <du 274 , du 274 >_{-1}^0.5 =  0.004100650625694638
# <du 275 , du 275 >_{-1}^0.5 =  0.004085582531441713
# <du 276 , du 276 >_{-1}^0.5 =  0.004070569537247973
# <du 277 , du 277 >_{-1}^0.5 =  0.0040556114426250145
# <du 278 , du 278 >_{-1}^0.5 =  0.004040708047893446
# <du 279 , du 279 >_{-1}^0.5 =  0.004025859154175701
# <du 280 , du 280 >_{-1}^0.5 =  0.004011064563389019
# <du 281 , du 281 >_{-1}^0.5 =  0.003996324078238339
# <du 282 , du 282 >_{-1}^0.5 =  0.003981637502209808
# <du 283 , du 283 >_{-1}^0.5 =  0.003967004639563986
# <du 284 , du 284 >_{-1}^0.5 =  0.003952425295329661
# <du 285 , du 285 >_{-1}^0.5 =  0.003937899275297455
# <du 286 , du 286 >_{-1}^0.5 =  0.003923426386013781
# <du 287 , du 287 >_{-1}^0.5 =  0.003909006434774997
# <du 288 , du 288 >_{-1}^0.5 =  0.0038946392296214387
# <du 289 , du 289 >_{-1}^0.5 =  0.0038803245793319987
# <du 290 , du 290 >_{-1}^0.5 =  0.0038660622934183894
# <du 291 , du 291 >_{-1}^0.5 =  0.003851852182119889
# <du 292 , du 292 >_{-1}^0.5 =  0.0038376940563980954
# <du 293 , du 293 >_{-1}^0.5 =  0.003823587727931708
# <du 294 , du 294 >_{-1}^0.5 =  0.0038095330091115717
# <du 295 , du 295 >_{-1}^0.5 =  0.003795529713035824
# <du 296 , du 296 >_{-1}^0.5 =  0.003781577653504922
# <du 297 , du 297 >_{-1}^0.5 =  0.0037676766450172546
# <du 298 , du 298 >_{-1}^0.5 =  0.003753826502764317
# <du 299 , du 299 >_{-1}^0.5 =  0.003740027042626347

# %%
Draw(gfu)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.22…
# BaseWebGuiScene

# %%
preJpoint = a.mat.CreateSmoother(fes.FreeDofs())
lams = EigenValues_Preconditioner(mat=a.mat, pre=preJpoint)
lams
# Out:
#  0.00368248
#   0.0161
#  0.0384545
#  0.0675765
#  0.0785148
#  0.118733
#  0.144691
#  0.198824
#  0.242989
#  0.311565
#  0.377593
#  0.424162
#  0.503678
#  0.580073
#  0.63626
#  0.713508
#  0.777349
#  0.855527
#  0.924361
#  0.996838
#  1.06931
#  1.12869
#  1.18864
#  1.24751
#  1.29539
#  1.34477
#  1.38959
#  1.42581
#  1.45738
#   1.4867
#  1.50711
#  1.51315
#  1.62075

# %%
max(lams)/min(lams)
# Out:
# 440.12320355595523

# %%
preI = Projector(mask=fes.FreeDofs(), range=True)

# %%
lams = EigenValues_Preconditioner(mat=a.mat, pre=preI)
max(lams)/min(lams)
# Out:
# 1560.1707162543955

# %%
# Out:
# CG iteration 1, residual = 0.05538055852845106
# CG iteration 2, residual = 0.09315935397110502
# CG iteration 3, residual = 0.10351189020825106
# CG iteration 4, residual = 0.0905534426369593
# CG iteration 5, residual = 0.09690655381637989
# CG iteration 6, residual = 0.08685499565444346
# CG iteration 7, residual = 0.09375145900717148
# CG iteration 8, residual = 0.08102545067766485
# CG iteration 9, residual = 0.051412733006382036
# CG iteration 10, residual = 0.043187032651892394
# CG iteration 11, residual = 0.03478485636733262
# CG iteration 12, residual = 0.027955532180578193
# CG iteration 13, residual = 0.02178641307580833
# CG iteration 14, residual = 0.019562562502518237
# CG iteration 15, residual = 0.013925054803092845
# CG iteration 16, residual = 0.01071769159551953
# CG iteration 17, residual = 0.009072032767387455
# CG iteration 18, residual = 0.006853407280989167
# CG iteration 19, residual = 0.0045606616783494276
# CG iteration 20, residual = 0.003188722005885527
# CG iteration 21, residual = 0.0018276845855752864
# CG iteration 22, residual = 0.0012509916643804622
# CG iteration 23, residual = 0.0010254914149442922
# CG iteration 24, residual = 0.0007220602502288788
# CG iteration 25, residual = 0.0004749807632415521
# CG iteration 26, residual = 0.00035124885126687266
# CG iteration 27, residual = 0.0002911953880497031
# CG iteration 28, residual = 0.00021826953595890846
# CG iteration 29, residual = 0.0001558486584143757
# CG iteration 30, residual = 0.00011137197511770406
# CG iteration 31, residual = 7.923058395297473e-05
# CG iteration 32, residual = 6.678061443918617e-05
# CG iteration 33, residual = 5.414048606023613e-05
# CG iteration 34, residual = 4.300294742383124e-05
# CG iteration 35, residual = 3.217682856039774e-05
# CG iteration 36, residual = 2.253783275211813e-05
# CG iteration 37, residual = 1.7312512352505226e-05
# CG iteration 38, residual = 1.4474897710791246e-05
# CG iteration 39, residual = 1.1166971332630108e-05
# CG iteration 40, residual = 7.78946322045075e-06
# CG iteration 41, residual = 5.430017564207647e-06
# CG iteration 42, residual = 3.955667003058552e-06
# CG iteration 43, residual = 2.744469036718688e-06
# CG iteration 44, residual = 2.0497454742785337e-06
# CG iteration 45, residual = 1.382416007445522e-06
# CG iteration 46, residual = 9.404899132299138e-07
# CG iteration 47, residual = 6.193600559936195e-07
# CG iteration 48, residual = 4.6248282128718526e-07
# CG iteration 49, residual = 3.3644148473155657e-07
# CG iteration 50, residual = 2.112556405469524e-07
# CG iteration 51, residual = 1.407769019653748e-07
# CG iteration 52, residual = 1.0212963934622633e-07
# CG iteration 53, residual = 7.829919436750489e-08
# CG iteration 54, residual = 5.4912295876519964e-08
# CG iteration 55, residual = 3.9110924839044415e-08
# CG iteration 56, residual = 2.7077299170450975e-08
# CG iteration 57, residual = 1.8662127040247458e-08
# CG iteration 58, residual = 1.1318713173128915e-08
# CG iteration 59, residual = 7.342292026961972e-09
# CG iteration 60, residual = 5.105617711019009e-09
# CG iteration 61, residual = 3.8871249696107885e-09
# CG iteration 62, residual = 2.716891087365592e-09
# CG iteration 63, residual = 1.6338567074695106e-09
# CG iteration 64, residual = 1.0507917188663716e-09
# CG iteration 65, residual = 7.386233293790315e-10
# CG iteration 66, residual = 5.838538490293243e-10
# CG iteration 67, residual = 4.374608762252166e-10
# CG iteration 68, residual = 3.006844477445971e-10
# CG iteration 69, residual = 1.911834961071679e-10
# CG iteration 70, residual = 1.0887946571375101e-10
# CG iteration 71, residual = 7.671368027074032e-11
# CG iteration 72, residual = 5.314368949868681e-11
# CG iteration 73, residual = 3.5605784734619577e-11
# CG iteration 74, residual = 2.3612549348009053e-11
# CG iteration 75, residual = 1.5841966757666807e-11
# CG iteration 76, residual = 1.0798034307164405e-11
# CG iteration 77, residual = 7.143662364804739e-12
# CG iteration 78, residual = 4.933643130636869e-12
# CG iteration 79, residual = 3.447652275556524e-12
# CG iteration 80, residual = 2.2686743245398965e-12
# CG iteration 81, residual = 1.3026588591988506e-12
# CG iteration 82, residual = 8.401833878071752e-13
# CG iteration 83, residual = 5.917311690673452e-13
# CG iteration 84, residual = 4.3738199363300346e-13
# CG iteration 85, residual = 2.9291689507984293e-13
# CG iteration 86, residual = 1.738064282721484e-13
# CG iteration 87, residual = 1.006279005828762e-13
# CG iteration 88, residual = 7.175414171543931e-14
# CG iteration 89, residual = 5.353935895074355e-14
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.22…
# BaseWebGuiScene
