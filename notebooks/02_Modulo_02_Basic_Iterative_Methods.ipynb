# %% [markdown]
# <hr style="border:2px solid #0176DE"> </hr>
# <center><h1 style="color:#173F8A;"> Escuela de Verano en Metodos Iterativos</h1></center>
# <center><h1 style="color:#173F8A;"> EMI 2024 - CMM Chile</h1></center>
# <hr style="border:2px solid #0176DE"> </hr>
# <h3 style="color:#173F8A;text-align:right;"> Profesores: &nbsp;Nicolas Barnafi<br>Manuel A. Sanchez<br></h3>
#
# <h3 style="color:#03122E;text-align:right;">
#     Centro de Modelamiento Matematico <br>
#     Instituto de Ingenieria Matematica y Computacional - IMC UC<br>
# </h3>
#
# <hr style="border:2px solid #03122E"> </hr>
# <center><h1 style="color:#173F8A;"> Modulo 2: Basic Iterative Methods</h1></center>
# <hr style="border:2px solid #03122E"> </hr>
#
# <!-- Palette colors UC:
# Primaria:
# celeste:#0176DE, azul #173F8A, azul oscuro: #03122E, amarillo: #FEC60D, amarillo oscuro: #E3AE00
# Secundaria
# gris oscuro: #707070
# -->

# %% [markdown]
# ## Objective: Review basic iterative Method for solving the linear systems.
#
# Let $A\in \mathbb R^{n\times n}$ and $b\in \mathbb R^{n}$. Consider the problem of finding $x\in \mathbb R^{n}$ such that
#
# $$
# Ax = b
# $$

# %% [markdown]
# ### General splitting for iteration methods.
#
# A basic iterative method given by the iteration
# $$
# M x_{k+1} = N x_{k} + b
# $$
# can be defined for any splitting of the form $A = M- N$ where $M$ is nonsingular. The matrix $G = M^{-1}N$ is known as the *iteration matrix* of the methods,
# $$
# x_{k+1} = G x_{k} + f, \quad f = M^{-1} b
# $$
#
# If the above iteration converges, its limit $x$ satisfies
#
# $$
# x = Gx + f
# $$
#
# In the case where the above iteration arises from the splitting $A=M-N$, it is easy to see that the solution $x$ to the above system is identical to that of the original system $Ax=b$. Indeed, in this case the sequence has the from
#
# $$
# x_{k+1} = M^{-1} N x_{k} + M^{-1} b
# $$
#
# and its limit satisfies
#
# $$
# Mx = Nx +b \quad \Longleftrightarrow \quad Ax = b
# $$

# %% [markdown]
# ### General convergence result
#
# ***Theorem***. Let $G$ be a square matrix such that $\rho(G)<1$. Then $(I-G)$ is nonsingular and the iteration $x_{k+1} = G x_{k} + f$ converges for any $f$ and $x_0$. Conversely, if the iteration converges for any $f$ and $x_0$, then $\rho(G)<1$.
#
# Here the spectal radius $\rho(A)$ of a matrix $A$ is defined as the maximum modulus of the eigenvalues of $A$, i.e.
#
# $$
# \rho(A) = \max_{\lambda \in \sigma(A)} |\lambda|
# $$
#
# ***Corollary***. Let $G$ be a square matrix such that $\|G\|<1$ for some matrix norm $\|\cdot\|$. Then $(I-G)$ is nonsingular and the iteration converges for any initial vector $x_0$.
#
# <h3 style="color:#0176DE">
#     How fast does the iteration converge?
# </h3>
#
# Define the error at step k $d_{k} = x_{k} - x_{*}$. Observe that
#
# $$
# d_{k} = x_{k} - x_{*} = G x_{k-1} + f - G x_{*} - f = G d_{k-1} = \ldots = G^{k} d_0
# $$
#
# <!-- The matrix $G$ can be expressed in the Jordan canonical form as $G = X J X^{-1}$. Assume for simplicity that there is only one eigenvalue of $G$ of largest modulus $\lambda = \rho(A)$. Then,
#
# $$
# d_{k} = \lambda^{k} X \left(\frac{1}{\lambda} J\right)^{k} X^{-1} d_0
# $$
#
# Only one Jordan block remains of size p $J_{\lambda} = \lambda I + E$, with $E$ nilpotente of index $p$. Then, for $k\geq p$
#
# $$
# J_{\lambda}^{k} = (\lambda I+E)^{k} = \lambda^{k}(I + \frac{1}{\lambda}E)^{k} = \lambda^{k} \left(\sum_{i=0}^{p-1} \lambda^{-i} {k \choose i}E^{i}\right)
# $$
#
# For any $\lambda$ the dominant term is the last term of $k$ arge enough
#
# $$
# J_{\lambda}^{k} \approx \lambda^{k-p+1} {k \choose p-1} E^{p-1}
# $$
#
# and thus,
#
# \|d_{k}\| \approx C |\lambda^{k-p+1}| {k \choose p-1}
#  -->
# A general convergence factor:
#
# $$
# \phi = \lim_{k\to \infty} \left( \max_{x_0\in \mathbb R^{n} } \frac{\|d_k\|}{\|d_0\|}\right)^{1/k}
# $$
#
# In this case
#
# $$
# \phi = \lim_{k \to \infty}\left( \max_{x_0\in \mathbb R^{n} } \frac{\|G^{k} d_0\|}{\|d_0\|}\right)^{1/k} = \lim_{k \to \infty}\left( \|G^{k}\|\right)^{1/k} = \rho(G).
# $$
#
# The global asymptotic factor is equal to the spectral radius of the iteration matrix.

# %% [markdown]
# #### Ejemplo: Richardson's iteration
# For $\alpha \geq 0$, consider the iteration
#
# $$
# x_{k+1} = x_{k} +\alpha (b-A x_{k})\quad \Longrightarrow \quad x_{k+1} = \underbrace{(I-\alpha A)}_{G_{\alpha}}x_{k} + \alpha b
# $$
#
# The convergence factor is $\rho(I-\alpha A)$. Assume that the eigenvalues $\lambda_i$, $1\leq i\leq n$,  of $A$ are all real and such that
#
# $$\lambda_{\min} \leq \lambda_i \leq \lambda_{\max} $$
#
# Then, the eigenvalues $\mu_i$ of $G_{\alpha}$ are such that
#
# $$ 1- \alpha\lambda_{\max} \leq \mu_i \leq 1 - \alpha \lambda_{\min} $$
#
# If $\lambda_{\min} < 0$ and $\lambda_{\max} >0 $ , at leaast one eigenvalue is $>1$, and so $\rho(G_{\alpha})>1$, for any $\alpha$,and the method diverges for any $x_0$.
#
# If all the eigenvalues are positive, $\lambda_{\min}>0$, then the method converges for any scalar $\alpha$ which satisfies
#
# $$
# 0<\alpha<2/\lambda_{\max}.
# $$
#
# Optimal $\alpha$?
#
# $$
# \alpha_{\text{opt}} = \frac{2}{\lambda_{\min} + \lambda_{\max}}
# $$

# %% [markdown]
# **Decomposition:** $ \quad A = D -E - F$, $D$ diagonal matrix, $E$ strict lower triangular, and $F$ strict upper triangular.
#
#
# #### Jacobi Iteration:
# $$
# x_{k+1} = D^{-1}(E+F)x_{k} + D^{-1}b
# $$
#
# $$
# x_{k+1} = -D^{-1}(A-D)x_{k} + D^{-1}b = -D^{-1}(A)x_{k} + x_{k}+ D^{-1}b
# $$
#
# $$
# x_{k+1} - x_{k}= \Delta x_{k+1}  = -D^{-1}(A)x_{k}+ D^{-1}b
# $$
#
# #### Gauss-Seidel Iteration:
# $$
# x_{k+1} = (D-E)^{-1} F x_{k} + (D-E)^{-1}b
# $$
#
# #### Successive Over Relaxation (SOR):
# $$
# (D-\omega E)x_{k+1} = \left( \omega F +(1-\omega)D\right) x_{k} + \omega b
# $$
#
# #### Symmetric SOR (SSOR):
# \begin{align*}
# (D-\omega E) x_{k+1/2} & = \left( \omega F + (1-\omega)D\right) x_{k} + \omega b \\
# (D-\omega F) x_{k+1} & = \left(\omega E + (1-\omega)D\right) x_{k+1/2} + \omega b
# \end{align*}

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from ngsolve.la import EigenValues_Preconditioner
import matplotlib.pyplot as plt

# %%
# Poisson problem
def Setup(h=0.01, p=1):
    mesh = Mesh(unit_square.GenerateMesh(maxh=h))
    fes = H1(mesh, order=p, dirichlet="left|bottom")
    u, v = fes.TnT()
    a = BilinearForm(grad(u)*grad(v)*dx + u*v*dx)
    f = LinearForm(v*dx)
    gfu = GridFunction(fes)
    return mesh, fes, a, f, gfu

# %%
mesh, fes, a, b, gfu = Setup(h=0.05, p=1)
a.Assemble()
b.Assemble();
Draw(gfu)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %%
def JacobiIteration(gfu, a, b, maxits=300, tol=1e-8):
    fes = gfu.space
    du = gfu.vec.CreateVector()
    res = gfu.vec.CreateVector()
    diag = (a.mat.CreateSmoother(fes.FreeDofs()))
    f = diag*b.vec
    for it in range(maxits):
        res.data = -a.mat*gfu.vec
        du.data = diag*res+ f
        gfu.vec.data += du
        
        #stopping criteria
        stopcritval = sqrt(abs(InnerProduct(du,du)))
        print ("<du",it,", du",it,">_{-1}^0.5 = ", stopcritval)
        if stopcritval < tol:
            break

# %%
JacobiIteration(gfu, a, b)
# Out:
# <du 0 , du 0 >_{-1}^0.5 =  0.013358700755285374
# <du 1 , du 1 >_{-1}^0.5 =  0.01292990106656973
# <du 2 , du 2 >_{-1}^0.5 =  0.012714356576574765
# <du 3 , du 3 >_{-1}^0.5 =  0.01255319949842176
# <du 4 , du 4 >_{-1}^0.5 =  0.01241509860314673
# <du 5 , du 5 >_{-1}^0.5 =  0.01229397109883573
# <du 6 , du 6 >_{-1}^0.5 =  0.012183204174095762
# <du 7 , du 7 >_{-1}^0.5 =  0.01208112671046888
# <du 8 , du 8 >_{-1}^0.5 =  0.011985285802130558
# <du 9 , du 9 >_{-1}^0.5 =  0.0118948364104292
# <du 10 , du 10 >_{-1}^0.5 =  0.011808643688965446
# <du 11 , du 11 >_{-1}^0.5 =  0.0117261877312027
# <du 12 , du 12 >_{-1}^0.5 =  0.011646865659044029
# <du 13 , du 13 >_{-1}^0.5 =  0.011570332523763858
# <du 14 , du 14 >_{-1}^0.5 =  0.011496233142290525
# <du 15 , du 15 >_{-1}^0.5 =  0.011424329143193766
# <du 16 , du 16 >_{-1}^0.5 =  0.011354393138223128
# <du 17 , du 17 >_{-1}^0.5 =  0.011286254955820507
# <du 18 , du 18 >_{-1}^0.5 =  0.011219758814464121
# <du 19 , du 19 >_{-1}^0.5 =  0.01115477939478494
# <du 20 , du 20 >_{-1}^0.5 =  0.011091203952804555
# <du 21 , du 21 >_{-1}^0.5 =  0.011028937385674809
# <du 22 , du 22 >_{-1}^0.5 =  0.010967894427097592
# <du 23 , du 23 >_{-1}^0.5 =  0.010908000856977526
# <du 24 , du 24 >_{-1}^0.5 =  0.01084918988559742
# <du 25 , du 25 >_{-1}^0.5 =  0.010791402119409942
# <du 26 , du 26 >_{-1}^0.5 =  0.01073458375256715
# <du 27 , du 27 >_{-1}^0.5 =  0.01067868620787161
# <du 28 , du 28 >_{-1}^0.5 =  0.010623665149358547
# <du 29 , du 29 >_{-1}^0.5 =  0.010569480098707115
# <du 30 , du 30 >_{-1}^0.5 =  0.010516093846263518
# <du 31 , du 31 >_{-1}^0.5 =  0.010463472125092915
# <du 32 , du 32 >_{-1}^0.5 =  0.01041158323087251
# <du 33 , du 33 >_{-1}^0.5 =  0.010360397763976894
# <du 34 , du 34 >_{-1}^0.5 =  0.010309888368084578
# <du 35 , du 35 >_{-1}^0.5 =  0.010260029530522822
# <du 36 , du 36 >_{-1}^0.5 =  0.010210797393653263
# <du 37 , du 37 >_{-1}^0.5 =  0.010162169600586015
# <du 38 , du 38 >_{-1}^0.5 =  0.01011412515415129
# <du 39 , du 39 >_{-1}^0.5 =  0.010066644296835237
# <du 40 , du 40 >_{-1}^0.5 =  0.01001970840249805
# <du 41 , du 41 >_{-1}^0.5 =  0.009973299881954731
# <du 42 , du 42 >_{-1}^0.5 =  0.009927402098128367
# <du 43 , du 43 >_{-1}^0.5 =  0.009881999290940763
# <du 44 , du 44 >_{-1}^0.5 =  0.00983707650974417
# <du 45 , du 45 >_{-1}^0.5 =  0.009792619552893045
# <du 46 , du 46 >_{-1}^0.5 =  0.009748614913210118
# <du 47 , du 47 >_{-1}^0.5 =  0.009705049728847495
# <du 48 , du 48 >_{-1}^0.5 =  0.009661911738764278
# <du 49 , du 49 >_{-1}^0.5 =  0.009619189242368825
# <du 50 , du 50 >_{-1}^0.5 =  0.009576871062799277
# <du 51 , du 51 >_{-1}^0.5 =  0.00953494651347043
# <du 52 , du 52 >_{-1}^0.5 =  0.00949340536751037
# <du 53 , du 53 >_{-1}^0.5 =  0.009452237829791002
# <du 54 , du 54 >_{-1}^0.5 =  0.009411434511272665
# <du 55 , du 55 >_{-1}^0.5 =  0.009370986405429889
# <du 56 , du 56 >_{-1}^0.5 =  0.009330884866545206
# <du 57 , du 57 >_{-1}^0.5 =  0.00929112158968775
# <du 58 , du 58 >_{-1}^0.5 =  0.009251688592211378
# <du 59 , du 59 >_{-1}^0.5 =  0.009212578196627835
# <du 60 , du 60 >_{-1}^0.5 =  0.00917378301472503
# <du 61 , du 61 >_{-1}^0.5 =  0.009135295932815925
# <du 62 , du 62 >_{-1}^0.5 =  0.009097110098014985
# <du 63 , du 63 >_{-1}^0.5 =  0.009059218905450734
# <du 64 , du 64 >_{-1}^0.5 =  0.009021615986332231
# <du 65 , du 65 >_{-1}^0.5 =  0.008984295196795796
# <du 66 , du 66 >_{-1}^0.5 =  0.008947250607465982
# <du 67 , du 67 >_{-1}^0.5 =  0.008910476493671307
# <du 68 , du 68 >_{-1}^0.5 =  0.00887396732626115
# <du 69 , du 69 >_{-1}^0.5 =  0.008837717762975563
# <du 70 , du 70 >_{-1}^0.5 =  0.008801722640324234
# <du 71 , du 71 >_{-1}^0.5 =  0.008765976965935321
# <du 72 , du 72 >_{-1}^0.5 =  0.008730475911338124
# <du 73 , du 73 >_{-1}^0.5 =  0.008695214805147325
# <du 74 , du 74 >_{-1}^0.5 =  0.008660189126619132
# <du 75 , du 75 >_{-1}^0.5 =  0.008625394499552713
# <du 76 , du 76 >_{-1}^0.5 =  0.008590826686512211
# <du 77 , du 77 >_{-1}^0.5 =  0.008556481583347183
# <du 78 , du 78 >_{-1}^0.5 =  0.008522355213991114
# <du 79 , du 79 >_{-1}^0.5 =  0.008488443725519122
# <du 80 , du 80 >_{-1}^0.5 =  0.008454743383448116
# <du 81 , du 81 >_{-1}^0.5 =  0.00842125056726346
# <du 82 , du 82 >_{-1}^0.5 =  0.008387961766157819
# <du 83 , du 83 >_{-1}^0.5 =  0.008354873574969017
# <du 84 , du 84 >_{-1}^0.5 =  0.008321982690304661
# <du 85 , du 85 >_{-1}^0.5 =  0.008289285906842235
# <du 86 , du 86 >_{-1}^0.5 =  0.008256780113794413
# <du 87 , du 87 >_{-1}^0.5 =  0.008224462291529832
# <du 88 , du 88 >_{-1}^0.5 =  0.00819232950834058
# <du 89 , du 89 >_{-1}^0.5 =  0.008160378917348065
# <du 90 , du 90 >_{-1}^0.5 =  0.008128607753539678
# <du 91 , du 91 >_{-1}^0.5 =  0.008097013330929109
# <du 92 , du 92 >_{-1}^0.5 =  0.008065593039833771
# <du 93 , du 93 >_{-1}^0.5 =  0.00803434434426314
# <du 94 , du 94 >_{-1}^0.5 =  0.008003264779412135
# <du 95 , du 95 >_{-1}^0.5 =  0.007972351949254653
# <du 96 , du 96 >_{-1}^0.5 =  0.007941603524231552
# <du 97 , du 97 >_{-1}^0.5 =  0.00791101723902903
# <du 98 , du 98 >_{-1}^0.5 =  0.007880590890442737
# <du 99 , du 99 >_{-1}^0.5 =  0.007850322335323396
# <du 100 , du 100 >_{-1}^0.5 =  0.007820209488600474
# <du 101 , du 101 >_{-1}^0.5 =  0.007790250321379767
# <du 102 , du 102 >_{-1}^0.5 =  0.007760442859111986
# <du 103 , du 103 >_{-1}^0.5 =  0.00773078517982876
# <du 104 , du 104 >_{-1}^0.5 =  0.007701275412443235
# <du 105 , du 105 >_{-1}^0.5 =  0.007671911735112437
# <du 106 , du 106 >_{-1}^0.5 =  0.007642692373658522
# <du 107 , du 107 >_{-1}^0.5 =  0.007613615600046624
# <du 108 , du 108 >_{-1}^0.5 =  0.007584679730916684
# <du 109 , du 109 >_{-1}^0.5 =  0.007555883126167175
# <du 110 , du 110 >_{-1}^0.5 =  0.007527224187588332
# <du 111 , du 111 >_{-1}^0.5 =  0.0074987013575431895
# <du 112 , du 112 >_{-1}^0.5 =  0.007470313117694086
# <du 113 , du 113 >_{-1}^0.5 =  0.007442057987773188
# <du 114 , du 114 >_{-1}^0.5 =  0.007413934524394995
# <du 115 , du 115 >_{-1}^0.5 =  0.00738594131990933
# <du 116 , du 116 >_{-1}^0.5 =  0.007358077001293156
# <du 117 , du 117 >_{-1}^0.5 =  0.007330340229079836
# <du 118 , du 118 >_{-1}^0.5 =  0.00730272969632416
# <du 119 , du 119 >_{-1}^0.5 =  0.007275244127602116
# <du 120 , du 120 >_{-1}^0.5 =  0.007247882278043784
# <du 121 , du 121 >_{-1}^0.5 =  0.007220642932398385
# <du 122 , du 122 >_{-1}^0.5 =  0.007193524904129961
# <du 123 , du 123 >_{-1}^0.5 =  0.007166527034542988
# <du 124 , du 124 >_{-1}^0.5 =  0.0071396481919364825
# <du 125 , du 125 >_{-1}^0.5 =  0.007112887270785671
# <du 126 , du 126 >_{-1}^0.5 =  0.007086243190950336
# <du 127 , du 127 >_{-1}^0.5 =  0.007059714896908779
# <du 128 , du 128 >_{-1}^0.5 =  0.007033301357016453
# <du 129 , du 129 >_{-1}^0.5 =  0.007007001562788536
# <du 130 , du 130 >_{-1}^0.5 =  0.00698081452820554
# <du 131 , du 131 >_{-1}^0.5 =  0.0069547392890410235
# <du 132 , du 132 >_{-1}^0.5 =  0.0069287749022109235
# <du 133 , du 133 >_{-1}^0.5 =  0.006902920445143515
# <du 134 , du 134 >_{-1}^0.5 =  0.006877175015169374
# <du 135 , du 135 >_{-1}^0.5 =  0.006851537728930714
# <du 136 , du 136 >_{-1}^0.5 =  0.006826007721809352
# <du 137 , du 137 >_{-1}^0.5 =  0.006800584147372729
# <du 138 , du 138 >_{-1}^0.5 =  0.006775266176837421
# <du 139 , du 139 >_{-1}^0.5 =  0.006750052998549417
# <du 140 , du 140 >_{-1}^0.5 =  0.006724943817480707
# <du 141 , du 141 >_{-1}^0.5 =  0.006699937854741694
# <du 142 , du 142 >_{-1}^0.5 =  0.006675034347108813
# <du 143 , du 143 >_{-1}^0.5 =  0.006650232546566784
# <du 144 , du 144 >_{-1}^0.5 =  0.006625531719865263
# <du 145 , du 145 >_{-1}^0.5 =  0.006600931148089175
# <du 146 , du 146 >_{-1}^0.5 =  0.006576430126242422
# <du 147 , du 147 >_{-1}^0.5 =  0.006552027962844485
# <du 148 , du 148 >_{-1}^0.5 =  0.006527723979539529
# <du 149 , du 149 >_{-1}^0.5 =  0.006503517510717554
# <du 150 , du 150 >_{-1}^0.5 =  0.0064794079031472674
# <du 151 , du 151 >_{-1}^0.5 =  0.006455394515620318
# <du 152 , du 152 >_{-1}^0.5 =  0.006431476718606318
# <du 153 , du 153 >_{-1}^0.5 =  0.00640765389391883
# <du 154 , du 154 >_{-1}^0.5 =  0.006383925434391073
# <du 155 , du 155 >_{-1}^0.5 =  0.006360290743562245
# <du 156 , du 156 >_{-1}^0.5 =  0.00633674923537283
# <du 157 , du 157 >_{-1}^0.5 =  0.006313300333869682
# <du 158 , du 158 >_{-1}^0.5 =  0.006289943472919993
# <du 159 , du 159 >_{-1}^0.5 =  0.006266678095933915
# <du 160 , du 160 >_{-1}^0.5 =  0.006243503655595808
# <du 161 , du 161 >_{-1}^0.5 =  0.006220419613603585
# <du 162 , du 162 >_{-1}^0.5 =  0.006197425440416128
# <du 163 , du 163 >_{-1}^0.5 =  0.006174520615008221
# <du 164 , du 164 >_{-1}^0.5 =  0.006151704624633134
# <du 165 , du 165 >_{-1}^0.5 =  0.006128976964592319
# <du 166 , du 166 >_{-1}^0.5 =  0.006106337138012173
# <du 167 , du 167 >_{-1}^0.5 =  0.006083784655627541
# <du 168 , du 168 >_{-1}^0.5 =  0.006061319035571813
# <du 169 , du 169 >_{-1}^0.5 =  0.006038939803173427
# <du 170 , du 170 >_{-1}^0.5 =  0.006016646490758474
# <du 171 , du 171 >_{-1}^0.5 =  0.005994438637459374
# <du 172 , du 172 >_{-1}^0.5 =  0.005972315789029299
# <du 173 , du 173 >_{-1}^0.5 =  0.005950277497662204
# <du 174 , du 174 >_{-1}^0.5 =  0.0059283233218183655
# <du 175 , du 175 >_{-1}^0.5 =  0.0059064528260551405
# <du 176 , du 176 >_{-1}^0.5 =  0.0058846655808628846
# <du 177 , du 177 >_{-1}^0.5 =  0.005862961162505785
# <du 178 , du 178 >_{-1}^0.5 =  0.005841339152867597
# <du 179 , du 179 >_{-1}^0.5 =  0.005819799139301907
# <du 180 , du 180 >_{-1}^0.5 =  0.0057983407144870155
# <du 181 , du 181 >_{-1}^0.5 =  0.005776963476285209
# <du 182 , du 182 >_{-1}^0.5 =  0.005755667027606108
# <du 183 , du 183 >_{-1}^0.5 =  0.005734450976274434
# <du 184 , du 184 >_{-1}^0.5 =  0.0057133149349015006
# <du 185 , du 185 >_{-1}^0.5 =  0.005692258520760636
# <du 186 , du 186 >_{-1}^0.5 =  0.005671281355666463
# <du 187 , du 187 >_{-1}^0.5 =  0.005650383065857683
# <du 188 , du 188 >_{-1}^0.5 =  0.005629563281883499
# <du 189 , du 189 >_{-1}^0.5 =  0.005608821638493343
# <du 190 , du 190 >_{-1}^0.5 =  0.005588157774529986
# <du 191 , du 191 >_{-1}^0.5 =  0.00556757133282587
# <du 192 , du 192 >_{-1}^0.5 =  0.005547061960102543
# <du 193 , du 193 >_{-1}^0.5 =  0.0055266293068730295
# <du 194 , du 194 >_{-1}^0.5 =  0.005506273027347315
# <du 195 , du 195 >_{-1}^0.5 =  0.005485992779340484
# <du 196 , du 196 >_{-1}^0.5 =  0.005465788224183687
# <du 197 , du 197 >_{-1}^0.5 =  0.005445659026637817
# <du 198 , du 198 >_{-1}^0.5 =  0.005425604854809736
# <du 199 , du 199 >_{-1}^0.5 =  0.005405625380070928
# <du 200 , du 200 >_{-1}^0.5 =  0.005385720276978802
# <du 201 , du 201 >_{-1}^0.5 =  0.005365889223200087
# <du 202 , du 202 >_{-1}^0.5 =  0.0053461318994367365
# <du 203 , du 203 >_{-1}^0.5 =  0.0053264479893539345
# <du 204 , du 204 >_{-1}^0.5 =  0.005306837179510233
# <du 205 , du 205 >_{-1}^0.5 =  0.005287299159289928
# <du 206 , du 206 >_{-1}^0.5 =  0.005267833620837256
# <du 207 , du 207 >_{-1}^0.5 =  0.005248440258992761
# <du 208 , du 208 >_{-1}^0.5 =  0.005229118771231291
# <du 209 , du 209 >_{-1}^0.5 =  0.005209868857602138
# <du 210 , du 210 >_{-1}^0.5 =  0.00519069022067079
# <du 211 , du 211 >_{-1}^0.5 =  0.005171582565462436
# <du 212 , du 212 >_{-1}^0.5 =  0.005152545599407164
# <du 213 , du 213 >_{-1}^0.5 =  0.005133579032286878
# <du 214 , du 214 >_{-1}^0.5 =  0.005114682576183603
# <du 215 , du 215 >_{-1}^0.5 =  0.005095855945429483
# <du 216 , du 216 >_{-1}^0.5 =  0.005077098856558252
# <du 217 , du 217 >_{-1}^0.5 =  0.005058411028258075
# <du 218 , du 218 >_{-1}^0.5 =  0.005039792181325834
# <du 219 , du 219 >_{-1}^0.5 =  0.005021242038622771
# <du 220 , du 220 >_{-1}^0.5 =  0.005002760325031383
# <du 221 , du 221 >_{-1}^0.5 =  0.004984346767413718
# <du 222 , du 222 >_{-1}^0.5 =  0.004966001094570812
# <du 223 , du 223 >_{-1}^0.5 =  0.00494772303720324
# <du 224 , du 224 >_{-1}^0.5 =  0.004929512327873131
# <du 225 , du 225 >_{-1}^0.5 =  0.004911368700966918
# <du 226 , du 226 >_{-1}^0.5 =  0.004893291892659497
# <du 227 , du 227 >_{-1}^0.5 =  0.004875281640879254
# <du 228 , du 228 >_{-1}^0.5 =  0.0048573376852742095
# <du 229 , du 229 >_{-1}^0.5 =  0.004839459767179159
# <du 230 , du 230 >_{-1}^0.5 =  0.004821647629583686
# <du 231 , du 231 >_{-1}^0.5 =  0.0048039010171012884
# <du 232 , du 232 >_{-1}^0.5 =  0.004786219675939182
# <du 233 , du 233 >_{-1}^0.5 =  0.004768603353869225
# <du 234 , du 234 >_{-1}^0.5 =  0.004751051800199506
# <du 235 , du 235 >_{-1}^0.5 =  0.004733564765746785
# <du 236 , du 236 >_{-1}^0.5 =  0.004716142002809905
# <du 237 , du 237 >_{-1}^0.5 =  0.004698783265143818
# <du 238 , du 238 >_{-1}^0.5 =  0.0046814883079343925
# <du 239 , du 239 >_{-1}^0.5 =  0.004664256887773857
# <du 240 , du 240 >_{-1}^0.5 =  0.004647088762637269
# <du 241 , du 241 >_{-1}^0.5 =  0.004629983691859347
# <du 242 , du 242 >_{-1}^0.5 =  0.004612941436112061
# <du 243 , du 243 >_{-1}^0.5 =  0.0045959617573829775
# <du 244 , du 244 >_{-1}^0.5 =  0.004579044418954082
# <du 245 , du 245 >_{-1}^0.5 =  0.004562189185381265
# <du 246 , du 246 >_{-1}^0.5 =  0.004545395822474514
# <du 247 , du 247 >_{-1}^0.5 =  0.004528664097278413
# <du 248 , du 248 >_{-1}^0.5 =  0.0045119937780534435
# <du 249 , du 249 >_{-1}^0.5 =  0.004495384634257734
# <du 250 , du 250 >_{-1}^0.5 =  0.004478836436529261
# <du 251 , du 251 >_{-1}^0.5 =  0.004462348956668725
# <du 252 , du 252 >_{-1}^0.5 =  0.004445921967622652
# <du 253 , du 253 >_{-1}^0.5 =  0.004429555243467276
# <du 254 , du 254 >_{-1}^0.5 =  0.0044132485593926215
# <du 255 , du 255 >_{-1}^0.5 =  0.004397001691687192
# <du 256 , du 256 >_{-1}^0.5 =  0.0043808144177230265
# <du 257 , du 257 >_{-1}^0.5 =  0.00436468651594119
# <du 258 , du 258 >_{-1}^0.5 =  0.004348617765837593
# <du 259 , du 259 >_{-1}^0.5 =  0.004332607947949437
# <du 260 , du 260 >_{-1}^0.5 =  0.004316656843841682
# <du 261 , du 261 >_{-1}^0.5 =  0.00430076423609419
# <du 262 , du 262 >_{-1}^0.5 =  0.004284929908289158
# <du 263 , du 263 >_{-1}^0.5 =  0.004269153644998707
# <du 264 , du 264 >_{-1}^0.5 =  0.004253435231773108
# <du 265 , du 265 >_{-1}^0.5 =  0.004237774455129079
# <du 266 , du 266 >_{-1}^0.5 =  0.004222171102538561
# <du 267 , du 267 >_{-1}^0.5 =  0.00420662496241769
# <du 268 , du 268 >_{-1}^0.5 =  0.004191135824116195
# <du 269 , du 269 >_{-1}^0.5 =  0.004175703477906892
# <du 270 , du 270 >_{-1}^0.5 =  0.004160327714975631
# <du 271 , du 271 >_{-1}^0.5 =  0.00414500832741151
# <du 272 , du 272 >_{-1}^0.5 =  0.004129745108197172
# <du 273 , du 273 >_{-1}^0.5 =  0.004114537851199506
# <du 274 , du 274 >_{-1}^0.5 =  0.0040993863511606665
# <du 275 , du 275 >_{-1}^0.5 =  0.004084290403689102
# <du 276 , du 276 >_{-1}^0.5 =  0.004069249805250971
# <du 277 , du 277 >_{-1}^0.5 =  0.004054264353161771
# <du 278 , du 278 >_{-1}^0.5 =  0.004039333845578212
# <du 279 , du 279 >_{-1}^0.5 =  0.0040244580814900845
# <du 280 , du 280 >_{-1}^0.5 =  0.004009636860712769
# <du 281 , du 281 >_{-1}^0.5 =  0.00399486998387938
# <du 282 , du 282 >_{-1}^0.5 =  0.003980157252433569
# <du 283 , du 283 >_{-1}^0.5 =  0.003965498468622339
# <du 284 , du 284 >_{-1}^0.5 =  0.003950893435488898
# <du 285 , du 285 >_{-1}^0.5 =  0.0039363419568660615
# <du 286 , du 286 >_{-1}^0.5 =  0.003921843837369301
# <du 287 , du 287 >_{-1}^0.5 =  0.003907398882390471
# <du 288 , du 288 >_{-1}^0.5 =  0.0038930068980913587
# <du 289 , du 289 >_{-1}^0.5 =  0.0038786676913974815
# <du 290 , du 290 >_{-1}^0.5 =  0.0038643810699921666
# <du 291 , du 291 >_{-1}^0.5 =  0.0038501468423104324
# <du 292 , du 292 >_{-1}^0.5 =  0.003835964817533491
# <du 293 , du 293 >_{-1}^0.5 =  0.003821834805582848
# <du 294 , du 294 >_{-1}^0.5 =  0.003807756617115097
# <du 295 , du 295 >_{-1}^0.5 =  0.0037937300635163098
# <du 296 , du 296 >_{-1}^0.5 =  0.0037797549568969226
# <du 297 , du 297 >_{-1}^0.5 =  0.003765831110086569
# <du 298 , du 298 >_{-1}^0.5 =  0.0037519583366290724
# <du 299 , du 299 >_{-1}^0.5 =  0.0037381364507776313

# %%
Draw(gfu)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %%
preJpoint = a.mat.CreateSmoother(fes.FreeDofs())
lams = EigenValues_Preconditioner(mat=a.mat, pre=preJpoint)
lams
# Out:
#  0.00369032
#  0.0160617
#  0.0309842
#  0.0414739
#  0.073478
#  0.119419
#  0.155745
#  0.189141
#  0.247056
#  0.305933
#  0.363765
#  0.407652
#  0.490682
#  0.560244
#  0.634201
#  0.714744
#  0.77319
#  0.855753
#  0.917618
#  0.986429
#   1.0612
#  1.12758
#  1.19148
#  1.24096
#   1.2988
#  1.33938
#  1.38801
#  1.42333
#   1.4595
#  1.48653
#  1.50644
#  1.51579
#   1.6187

# %%
max(lams)/min(lams)
# Out:
# 438.633404830515

# %%
preI = Projector(mask=fes.FreeDofs(), range=True)

# %%
lams = EigenValues_Preconditioner(mat=a.mat, pre=preI)
max(lams)/min(lams)
# Out:
# 455.7612101866214
